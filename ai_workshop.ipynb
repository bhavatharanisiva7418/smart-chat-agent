# %%
# %%writefile .env
# GROQ_API_KEY='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'
# Out:
# Overwriting .env

# %%
GROQ_API_KEY='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'

# %%
pip install dotenv
# Out:
# Requirement already satisfied: dotenv in /usr/local/lib/python3.12/dist-packages (0.9.9)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from dotenv) (1.2.1)

# %%
pip install groq
# Out:
# Requirement already satisfied: groq in /usr/local/lib/python3.12/dist-packages (0.33.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from groq) (2.11.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.12/dist-packages (from groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->groq) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.4.2)

# %%
pip install phidata
# Out:
# Requirement already satisfied: phidata in /usr/local/lib/python3.12/dist-packages (2.7.10)
# Requirement already satisfied: docstring-parser in /usr/local/lib/python3.12/dist-packages (from phidata) (0.17.0)
# Requirement already satisfied: gitpython in /usr/local/lib/python3.12/dist-packages (from phidata) (3.1.45)
# Requirement already satisfied: httpx in /usr/local/lib/python3.12/dist-packages (from phidata) (0.28.1)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from phidata) (2.11.10)
# Requirement already satisfied: pydantic-settings in /usr/local/lib/python3.12/dist-packages (from phidata) (2.11.0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from phidata) (1.2.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from phidata) (6.0.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from phidata) (13.9.4)
# Requirement already satisfied: tomli in /usr/local/lib/python3.12/dist-packages (from phidata) (2.3.0)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from phidata) (0.20.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from phidata) (4.15.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython->phidata) (4.0.12)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx->phidata) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx->phidata) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx->phidata) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx->phidata) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx->phidata) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->phidata) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->phidata) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->phidata) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->phidata) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->phidata) (2.19.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer->phidata) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->phidata) (1.5.4)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython->phidata) (5.0.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->phidata) (0.1.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx->phidata) (1.3.1)

# %%
from phi.agent import Agent
from phi.model.groq import Groq
from dotenv import load_dotenv

# %%
from dotenv import load_dotenv
import os

load_dotenv()
print("Loaded key:", os.getenv("GROQ_API_KEY"))
# Out:
# Loaded key: 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

# %%
# !pip install phidata groq python-dotenv > /dev/null

from phi.agent import Agent
from phi.model.groq import Groq
import os
os.environ["GROQ_API_KEY"] = "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"
chatbot = Agent(
    name="Enterprise Assistant",
    model=Groq(id="llama-3.3-70b-versatile"),
    description="An intelligent chatbot to assist employees with HR, IT, and company-related queries."
)

print("🤖 Intelligent Enterprise Assistant is ready! Type 'exit' to stop.\n")
while True:
    user_input = input("You: ")
    if user_input.lower() in ["exit", "quit", "bye"]:
        print("Bot: Goodbye! Have a productive day!")
        break
    response = chatbot.run(user_input)
    print("Bot:", response)
# Out:
# 🤖 Intelligent Enterprise Assistant is ready! Type 'exit' to stop.
#
# Bot: content="Hello. I'm here to help you with any questions or concerns you may have related to HR, IT, or company-related matters. How can I assist you today?" content_type='str' event='RunResponse' messages=[Message(role='system', content='An intelligent chatbot to assist employees with HR, IT, and company-related queries.', name=None, tool_call_id=None, tool_calls=None, audio=None, images=None, videos=None, tool_name=None, tool_args=None, tool_call_error=None, stop_after_tool_call=False, metrics={}, references=None, created_at=1762746252), Message(role='user', content='hi', name=None, tool_call_id=None, tool_calls=None, audio=None, images=None, videos=None, tool_name=None, tool_args=None, tool_call_error=None, stop_after_tool_call=False, metrics={}, references=None, created_at=1762746252), Message(role='assistant', content="Hello. I'm here to help you with any questions or concerns you may have related to HR, IT, or company-related matters. How can I assist you today?", name=None, tool_call_id=None, tool_calls=None, audio=None, images=None, videos=None, tool_name=None, tool_args=None, tool_call_error=None, stop_after_tool_call=False, metrics={'time': 0.3318574090000084, 'input_tokens': 53, 'prompt_tokens': 53, 'output_tokens': 35, 'completion_tokens': 35, 'total_tokens': 88, 'completion_time': 0.086023976, 'prompt_time': 0.0017379, 'queue_time': 0.091516897, 'total_time': 0.087761876}, references=None, created_at=1762746252)] metrics=defaultdict(<class 'list'>, {'time': [0.3318574090000084], 'input_tokens': [53], 'prompt_tokens': [53], 'output_tokens': [35], 'completion_tokens': [35], 'total_tokens': [88], 'completion_time': [0.086023976], 'prompt_time': [0.0017379], 'queue_time': [0.091516897], 'total_time': [0.087761876]}) model='llama-3.3-70b-versatile' run_id='68ee5705-050d-4d1c-8034-5cdb4b1c0a3f' agent_id='792d1d75-3c15-4261-946f-9430b3fbfccc' session_id='6087279b-434e-4d92-9680-4d0f41a0d979' workflow_id=None tools=None images=None videos=None audio=None response_audio=None extra_data=None created_at=1762745927
# Bot: content="I'm doing well, thanks for asking. I'm a large language model, so I don't have feelings or emotions like humans do, but I'm always happy to help with any questions or tasks you might have. How can I assist you today? Do you have any HR, IT, or company-related queries?" content_type='str' event='RunResponse' messages=[Message(role='system', content='An intelligent chatbot to assist employees with HR, IT, and company-related queries.', name=None, tool_call_id=None, tool_calls=None, audio=None, images=None, videos=None, tool_name=None, tool_args=None, tool_call_error=None, stop_after_tool_call=False, metrics={}, references=None, created_at=1762746288), Message(role='user', content='how are you', name=None, tool_call_id=None, tool_calls=None, audio=None, images=None, videos=None, tool_name=None, tool_args=None, tool_call_error=None, stop_after_tool_call=False, metrics={}, references=None, created_at=1762746288), Message(role='assistant', content="I'm doing well, thanks for asking. I'm a large language model, so I don't have feelings or emotions like humans do, but I'm always happy to help with any questions or tasks you might have. How can I assist you today? Do you have any HR, IT, or company-related queries?", name=None, tool_call_id=None, tool_calls=None, audio=None, images=None, videos=None, tool_name=None, tool_args=None, tool_call_error=None, stop_after_tool_call=False, metrics={'time': 0.29586386000005405, 'input_tokens': 55, 'prompt_tokens': 55, 'output_tokens': 65, 'completion_tokens': 65, 'total_tokens': 120, 'completion_time': 0.133774435, 'prompt_time': 0.001665694, 'queue_time': 0.041733295, 'total_time': 0.135440129}, references=None, created_at=1762746288)] metrics=defaultdict(<class 'list'>, {'time': [0.29586386000005405], 'input_tokens': [55], 'prompt_tokens': [55], 'output_tokens': [65], 'completion_tokens': [65], 'total_tokens': [120], 'completion_time': [0.133774435], 'prompt_time': [0.001665694], 'queue_time': [0.041733295], 'total_time': [0.135440129]}) model='llama-3.3-70b-versatile' run_id='cb84cbb1-019d-49c8-b3dc-f460fc1640c5' agent_id='792d1d75-3c15-4261-946f-9430b3fbfccc' session_id='6087279b-434e-4d92-9680-4d0f41a0d979' workflow_id=None tools=None images=None videos=None audio=None response_audio=None extra_data=None created_at=1762745927
# Bot: content='Hello. How can I assist you today? Do you have any HR, IT, or company-related questions?' content_type='str' event='RunResponse' messages=[Message(role='system', content='An intelligent chatbot to assist employees with HR, IT, and company-related queries.', name=None, tool_call_id=None, tool_calls=None, audio=None, images=None, videos=None, tool_name=None, tool_args=None, tool_call_error=None, stop_after_tool_call=False, metrics={}, references=None, created_at=1762746861), Message(role='user', content='hi', name=None, tool_call_id=None, tool_calls=None, audio=None, images=None, videos=None, tool_name=None, tool_args=None, tool_call_error=None, stop_after_tool_call=False, metrics={}, references=None, created_at=1762746861), Message(role='assistant', content='Hello. How can I assist you today? Do you have any HR, IT, or company-related questions?', name=None, tool_call_id=None, tool_calls=None, audio=None, images=None, videos=None, tool_name=None, tool_args=None, tool_call_error=None, stop_after_tool_call=False, metrics={'time': 0.2602044959999148, 'input_tokens': 53, 'prompt_tokens': 53, 'output_tokens': 23, 'completion_tokens': 23, 'total_tokens': 76, 'completion_time': 0.050862817, 'prompt_time': 0.002415419, 'queue_time': 0.099562139, 'total_time': 0.053278236}, references=None, created_at=1762746861)] metrics=defaultdict(<class 'list'>, {'time': [0.2602044959999148], 'input_tokens': [53], 'prompt_tokens': [53], 'output_tokens': [23], 'completion_tokens': [23], 'total_tokens': [76], 'completion_time': [0.050862817], 'prompt_time': [0.002415419], 'queue_time': [0.099562139], 'total_time': [0.053278236]}) model='llama-3.3-70b-versatile' run_id='79003815-f9d7-41dc-8a83-3eaab321e394' agent_id='792d1d75-3c15-4261-946f-9430b3fbfccc' session_id='6087279b-434e-4d92-9680-4d0f41a0d979' workflow_id=None tools=None images=None videos=None audio=None response_audio=None extra_data=None created_at=1762745927
